# %% [markdown]
# # **Vector Data / Spatial Analysis**

# %% [markdown]
# Created by [Your Name]
#
# [mm/dd/yyyy]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Part 1: John Snow Cholera Maps**
#
# ---

# %% [markdown]
# ### **1a: Water Pump Buffer Map**

# %% [markdown]
# Below is a map of cholera deaths inside a 100m buffer of water pumps in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1VBlPBtjsS6MmT29MqMltKkfDvqOWQqhu/view?usp=drive_link
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1VBlPBtjsS6MmT29MqMltKkfDvqOWQqhu
# ```
#
# Reminder of the rendering syntax:
#
# ![pump buffer](https://drive.google.com/uc?export=view&id=1VBlPBtjsS6MmT29MqMltKkfDvqOWQqhu)
#
#
# <mark>Insert the map below:</mark>

# %% [markdown]
# ### **1b: Cholera Deaths Heatmap**

# %% [markdown]
# Below is a heatmap of cholera deaths in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1WqI1dvdFvOeacvns-qi3IhHJYItbS8_M/view?usp=drive_link
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1WqI1dvdFvOeacvns-qi3IhHJYItbS8_M
# ```
#
# Reminder of the rendering syntax:
#
# ![heatmap](https://drive.google.com/uc?export=view&id=1WqI1dvdFvOeacvns-qi3IhHJYItbS8_M)
#
#
# <mark>Insert the map below:</mark>

# %% [markdown]
# ## **Part 2: Campgrounds**
#
# ---

# %% [markdown]
# Below is a map of sites suitable for campgrounds on private land near Hugo Lake, MN.
#
# ```markdown
# https://drive.google.com/file/d/10pMSgseUDKjv0x6EI4ycNOulZ31SwsKV/view?usp=drive_link
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=10pMSgseUDKjv0x6EI4ycNOulZ31SwsKV
# ```
#
# Reminder of the rendering syntax:
#
# ![private land](https://drive.google.com/uc?export=view&id=10pMSgseUDKjv0x6EI4ycNOulZ31SwsKV)
#
#
# <mark>Insert the map below:</mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 10 Assignment.**</mark>
