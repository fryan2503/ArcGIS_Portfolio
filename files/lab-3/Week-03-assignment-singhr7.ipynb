# %% [markdown]
# # **Projecting Geographic Data**

# %% [markdown]
# Created by Ryan Singh
#
#
# [09/16/2025]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to my own Google Drive

# %% [markdown]
# ## **Map of Minnesota Counties**

# %% [markdown]
# Below is a map of Minnesota counties prepared following the Assignment #3 Guide
#
# ```markdown
# [Insert the original shareable link from Google Drive for the map you created this week]
# ```
#
# Create a viewable link of the map.
# - Delete `view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
# https://drive.google.com/file/d/1qixEevnGjtnB5cGeR08yZphqfvfp-_DP/view?usp=sharing
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1qixEevnGjtnB5cGeR08yZphqfvfp-_DP
#
# ```
#
# Insert the map below using the rendering syntax:
#
# ![MN map](https://drive.google.com/uc?export=view&id=1qixEevnGjtnB5cGeR08yZphqfvfp-_DP
# )
#
#
# <mark>![MN map](revised link)</mark>

# %% [markdown]
# ## **Coordinates of selected points in Minnesota map**
#
# | Point      | X coordinate (lon)  | Y coordinate (lat) |
# | ------- | --------------------- |------------------- |
# | Northeast corner of Ramsey County     | 92.8839606°W  | 45.0386341°N |

# %% [markdown]
# ## **Information of the coordinate systems**
#
# - By checking the **`Layer Properties`**, we can obtain the following info about the coordinate system used in map
#
# I am inpoutting the data for minnsota counties
#
#
# | Variable      | Information  |
# | ----------------------------- | -------------------------- |
# | Projection used in map     | NAD 1983 UTM Zone 15N  |
# | Projection zone number     | 16    |
# | Geograpphic Coordinate System      | NAD 1983   |
# | Datum | D North American 1983|

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 3 assignment.**</mark>

# %% [markdown]
# ## **Reference**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)

# %% [markdown]
# # Notes
# NE Ramsey = 92.8839606°W 45.0386341°N
